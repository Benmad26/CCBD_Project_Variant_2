# %% [markdown]
# # CCBD SP26 – Variant 2: Partitioning Strategies
# ## Analysis Notebook
#
# This notebook loads the benchmark results from `results.csv` and produces **interactive plots** with filters.
# Use the dropdowns, toggles and checkboxes below each section to explore results across layouts and dataset sizes.
#
# **Metrics analysed:**
# - Object count and storage size per layout
# - S3 listing time
# - Upload and download throughput
# - Selective query runtime
# - Broad query runtime

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display
import numpy as np

df = pd.read_csv("results.csv")

SIZES        = ["S", "M", "L"]
LAYOUT_ORDER = ["flat", "by_date", "by_region"]
COLORS       = {"flat": "#4C72B0", "by_date": "#DD8452", "by_region": "#55A868"}

df
# Out:
#   size     layout  local_listing_time_s  local_file_count  \
# 0    S       flat                0.0002                 1
# 1    S    by_date                0.0043               157
# 2    S  by_region                0.0013                25
# 3    M       flat                0.0002                 1
# 4    M    by_date                0.0195               784
# 5    M  by_region                0.0030               125
# 6    L       flat                0.0002                 1
# 7    L    by_date                0.1022              3136
# 8    L  by_region                0.0252               500
#
#    local_total_size_gb  s3_listing_time_s  s3_object_count  s3_total_size_gb  \
# 0               0.0737             0.0531                1            0.0737
# 1               0.1060             1.7661              157            0.1060
# 2               0.1029             0.3259               25            0.1029
# ...

# %% [markdown]
# ## 1. Object Count and Storage Size
#
# Select a metric and a dataset size to explore how many files each layout produces and how much storage it uses.
# Partitioned layouts generate significantly more files due to Hive directory structure,
# and are ~40% larger than flat due to per-file Parquet metadata overhead.

# %%
metric_selector = widgets.Dropdown(
    options=[("Number of files", "local_file_count"), ("Storage size (GB)", "local_total_size_gb")],
    value="local_file_count",
    description="Metric:",
    style={"description_width": "initial"},
)
size_toggle_1 = widgets.ToggleButtons(
    options=["S", "M", "L", "All"],
    value="All",
    description="Dataset size:",
    style={"description_width": "initial"},
)

def plot_storage(metric, size_filter):
    sizes = SIZES if size_filter == "All" else [size_filter]
    fig, ax = plt.subplots(figsize=(7, 4))
    x = np.arange(len(sizes))
    width = 0.25
    for i, layout in enumerate(LAYOUT_ORDER):
        subset = df[df["layout"] == layout].set_index("size").reindex(sizes)
        bars = ax.bar(x + i * width, subset[metric], width, label=layout,
                      color=COLORS[layout], edgecolor="white")
        for bar in bars:
            h = bar.get_height()
            ax.text(bar.get_x() + bar.get_width() / 2, h * 1.01,
                    f"{h:,.0f}" if metric == "local_file_count" else f"{h:.3f}",
                    ha="center", va="bottom", fontsize=8)
    label = "Number of files" if metric == "local_file_count" else "Size (GB)"
    ax.set_ylabel(label)
    ax.set_xticks(x + width)
    ax.set_xticklabels([f"Size {s}" for s in sizes])
    ax.set_title(f"{label} by layout")
    ax.legend(title="Layout")
    ax.spines[["top", "right"]].set_visible(False)
    plt.tight_layout()
    plt.show()

out1 = widgets.interactive_output(plot_storage, {"metric": metric_selector, "size_filter": size_toggle_1})
display(widgets.VBox([widgets.HBox([metric_selector, size_toggle_1]), out1]))

# %% [markdown]
# ## 2. S3 Listing Time
#
# Listing time measures how long it takes to enumerate all objects under a prefix via the S3 API.
# With 3,136 objects at size L, by_date takes **33 seconds** to list — over 4,000x slower than flat.
# Toggle between S3 and local listing to see the difference.

# %%
layout_checks = widgets.SelectMultiple(
    options=LAYOUT_ORDER,
    value=LAYOUT_ORDER,
    description="Layouts:",
    style={"description_width": "initial"},
    rows=3,
)
listing_toggle = widgets.RadioButtons(
    options=[("S3 listing", "s3_listing_time_s"), ("Local listing", "local_listing_time_s")],
    value="s3_listing_time_s",
    description="Source:",
    style={"description_width": "initial"},
)

def plot_listing(layouts, metric):
    if not layouts:
        print("Select at least one layout.")
        return
    layouts = [l for l in LAYOUT_ORDER if l in layouts]
    fig, axes = plt.subplots(1, 3, figsize=(12, 4))
    title = "S3 listing time" if metric == "s3_listing_time_s" else "Local listing time"
    fig.suptitle(f"{title} (seconds) — lower is better", fontsize=12)
    for i, size in enumerate(SIZES):
        subset = df[(df["size"] == size) & (df["layout"].isin(layouts))].set_index("layout").reindex(layouts)
        bars = axes[i].bar(subset.index, subset[metric],
                           color=[COLORS[l] for l in subset.index], edgecolor="white")
        for bar in bars:
            h = bar.get_height()
            axes[i].text(bar.get_x() + bar.get_width() / 2, h * 1.01,
                         f"{h:.3f}s", ha="center", va="bottom", fontsize=8)
        axes[i].set_title(f"Size {size}")
        axes[i].set_ylabel("Seconds" if i == 0 else "")
        axes[i].spines[["top", "right"]].set_visible(False)
    plt.tight_layout()
    plt.show()

out2 = widgets.interactive_output(plot_listing, {"layouts": layout_checks, "metric": listing_toggle})
display(widgets.VBox([widgets.HBox([layout_checks, listing_toggle]), out2]))

# %% [markdown]
# ## 3. Upload and Download Throughput
#
# Select which direction (upload or download) and which sizes to compare.
# Throughput is measured on a single representative sample file per layout.
# Flat achieves up to 30x higher upload throughput than by_date at size L.

# %%
direction = widgets.RadioButtons(
    options=[("Upload", "upload_throughput_mbs"), ("Download", "download_throughput_mbs")],
    value="upload_throughput_mbs",
    description="Direction:",
    style={"description_width": "initial"},
)
size_checks = widgets.SelectMultiple(
    options=SIZES,
    value=SIZES,
    description="Sizes:",
    rows=3,
    style={"description_width": "initial"},
)

def plot_throughput(metric, sizes):
    if not sizes:
        print("Select at least one size.")
        return
    sizes = [s for s in SIZES if s in sizes]
    fig, ax = plt.subplots(figsize=(7, 4))
    x = np.arange(len(sizes))
    width = 0.25
    for i, layout in enumerate(LAYOUT_ORDER):
        subset = df[df["layout"] == layout].set_index("size").reindex(sizes)
        bars = ax.bar(x + i * width, subset[metric], width, label=layout,
                      color=COLORS[layout], edgecolor="white")
        for bar in bars:
            h = bar.get_height()
            ax.text(bar.get_x() + bar.get_width() / 2, h * 1.01,
                    f"{h:.0f}", ha="center", va="bottom", fontsize=8)
    label = "Upload (MB/s)" if metric == "upload_throughput_mbs" else "Download (MB/s)"
    ax.set_ylabel(label)
    ax.set_xticks(x + width)
    ax.set_xticklabels([f"Size {s}" for s in sizes])
    ax.set_title(f"{label} by layout")
    ax.legend(title="Layout")
    ax.spines[["top", "right"]].set_visible(False)
    plt.tight_layout()
    plt.show()

out3 = widgets.interactive_output(plot_throughput, {"metric": direction, "sizes": size_checks})
display(widgets.VBox([widgets.HBox([direction, size_checks]), out3]))

# %% [markdown]
# ## 4. Query Runtime Comparison
#
# Select the query type and dataset size to compare layouts.
# - **Selective query**: filters on `region = "Zurich"` and a 3-day date range — partition pruning applies.
# - **Broad query**: full scan, no filter — all files must be opened, file-count overhead dominates.

# %%
query_type = widgets.RadioButtons(
    options=[("Selective query", "selective_time_s"), ("Broad query", "broad_time_s")],
    value="selective_time_s",
    description="Query type:",
    style={"description_width": "initial"},
)
size_toggle_4 = widgets.ToggleButtons(
    options=["S", "M", "L", "All"],
    value="All",
    description="Dataset size:",
    style={"description_width": "initial"},
)

def plot_query(metric, size_filter):
    sizes = SIZES if size_filter == "All" else [size_filter]
    ncols = len(sizes)
    fig, axes = plt.subplots(1, ncols, figsize=(4 * ncols, 4))
    if ncols == 1:
        axes = [axes]
    label = "Selective query time (s)" if metric == "selective_time_s" else "Broad query time (s)"
    fig.suptitle(f"{label} — lower is better", fontsize=12)
    for i, size in enumerate(sizes):
        subset = df[df["size"] == size].set_index("layout").reindex(LAYOUT_ORDER)
        bars = axes[i].bar(LAYOUT_ORDER, subset[metric],
                           color=[COLORS[l] for l in LAYOUT_ORDER], edgecolor="white")
        for bar in bars:
            h = bar.get_height()
            axes[i].text(bar.get_x() + bar.get_width() / 2, h * 1.01,
                         f"{h:.3f}s", ha="center", va="bottom", fontsize=8)
        axes[i].set_title(f"Size {size}")
        axes[i].set_ylabel("Seconds" if i == 0 else "")
        axes[i].spines[["top", "right"]].set_visible(False)
    plt.tight_layout()
    plt.show()

out4 = widgets.interactive_output(plot_query, {"metric": query_type, "size_filter": size_toggle_4})
display(widgets.VBox([widgets.HBox([query_type, size_toggle_4]), out4]))

# %% [markdown]
# ## 5. Head-to-Head Layout Comparison
#
# Select two layouts and a dataset size to compare them directly across all metrics at once.

# %%
layout_a = widgets.Dropdown(
    options=LAYOUT_ORDER, value="flat", description="Layout A:",
    style={"description_width": "initial"},
)
layout_b = widgets.Dropdown(
    options=LAYOUT_ORDER, value="by_region", description="Layout B:",
    style={"description_width": "initial"},
)
size_h2h = widgets.Dropdown(
    options=SIZES, value="L", description="Dataset size:",
    style={"description_width": "initial"},
)

METRICS_H2H = [
    ("s3_listing_time_s",       "S3 listing (s)"),
    ("upload_throughput_mbs",   "Upload (MB/s)"),
    ("download_throughput_mbs", "Download (MB/s)"),
    ("selective_time_s",        "Selective (s)"),
    ("broad_time_s",            "Broad (s)"),
]

def plot_h2h(la, lb, size):
    if la == lb:
        print("Select two different layouts.")
        return
    row_a = df[(df["layout"] == la) & (df["size"] == size)].iloc[0]
    row_b = df[(df["layout"] == lb) & (df["size"] == size)].iloc[0]
    keys   = [m[0] for m in METRICS_H2H]
    labels = [m[1] for m in METRICS_H2H]
    vals_a = [row_a[k] for k in keys]
    vals_b = [row_b[k] for k in keys]
    x = np.arange(len(keys))
    width = 0.35
    fig, ax = plt.subplots(figsize=(10, 4))
    bars_a = ax.bar(x - width/2, vals_a, width, label=la, color=COLORS[la], edgecolor="white")
    bars_b = ax.bar(x + width/2, vals_b, width, label=lb, color=COLORS[lb], edgecolor="white")
    for bar in list(bars_a) + list(bars_b):
        h = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, h * 1.01,
                f"{h:.2f}", ha="center", va="bottom", fontsize=8)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.set_title(f"Head-to-head: {la} vs {lb} — Size {size}")
    ax.legend(title="Layout")
    ax.spines[["top", "right"]].set_visible(False)
    plt.tight_layout()
    plt.show()

out5 = widgets.interactive_output(plot_h2h, {"la": layout_a, "lb": layout_b, "size": size_h2h})
display(widgets.VBox([widgets.HBox([layout_a, layout_b, size_h2h]), out5]))
